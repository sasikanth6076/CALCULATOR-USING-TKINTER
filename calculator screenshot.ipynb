# %%
import matplotlib.pyplot as plt        
import matplotlib.image as mpimg    

Before_Img = mpimg.imread(r"C:/Users/sasikanthchowdhary.n/Downloads/calculator_screenshot.png")   
plt.imshow(Before_Img)               
plt.axis('off')                 
plt.show()
